# %% [markdown]
# # Import Dataset Nasabah Bank

# %%
import pandas as pd
dataset = pd.read_csv('bank_customers.csv')
X = dataset.iloc[:, 3:13 ].values   # Pilah Fitur yang penting (Dari CreditScore - EstimatedSalary)
y = dataset.iloc[:, 13 ].values     # Pilah Jawaban (Exited)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder as ohe
from sklearn.compose import ColumnTransformer as ct
le = LabelEncoder()
X[:, 1] = le.fit_transform(X[:, 1]) # Ubah nama negara menjadi numerik
X[:, 2] = le.fit_transform(X[:, 2]) # Ubah gender menjadi numerik
Setarakan = ct([('Pilah Jadi 3', ohe(), [1])], remainder="passthrough")
X = Setarakan.fit_transform(X[:,0:]) # Setarakan kategori negara
X = X[:, 1:]  # hilangkan 1 fitur variabel sampah

# %% [markdown]
# # Pilah Data Latihan dengan Data Ujian

# %%
from sklearn.model_selection import train_test_split as tts
Soal_latihan, Soal_ujian, Jawaban_latihan, Jawaban_ujian = tts(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Standarisasi Soal Latihan dan Soal Ujian

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
Soal_latihan = ss.fit_transform(Soal_latihan)  # Standarisasi Soal Latihan
Soal_ujian = ss.transform(Soal_ujian)          # Standarisasi Soal Ujian

# %% [markdown]
# # Inisialisasi Arsitektur ANN (11-6-6-1)

# %%
from keras.models import Sequential
from keras.layers import Dense as layerHiddennya
modelnya = Sequential()
modelnya.add(layerHiddennya(6, activation = 'relu', input_dim = 11))
modelnya.add(layerHiddennya(6, activation = 'relu'))
modelnya.add(layerHiddennya(1, activation = 'sigmoid'))
modelnya.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics = ['accuracy'])
modelnya.fit(Soal_latihan, Jawaban_latihan, batch_size= 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 1s 894us/step - loss: 0.6515 - accuracy: 0.6230
# Epoch 2/100
# 800/800 [==============================] - 1s 895us/step - loss: 0.4650 - accuracy: 0.7999
# Epoch 3/100
# 800/800 [==============================] - 1s 913us/step - loss: 0.4158 - accuracy: 0.8234
# Epoch 4/100
# 800/800 [==============================] - 1s 915us/step - loss: 0.3929 - accuracy: 0.8347
# Epoch 5/100
# 800/800 [==============================] - 1s 919us/step - loss: 0.3834 - accuracy: 0.8341
# Epoch 6/100
# 800/800 [==============================] - 1s 884us/step - loss: 0.3665 - accuracy: 0.8478
# Epoch 7/100
# 800/800 [==============================] - 1s 874us/step - loss: 0.3605 - accuracy: 0.8537
# Epoch 8/100
# 800/800 [==============================] - 1s 931us/step - loss: 0.3624 - accuracy: 0.8557
# Epoch 9/100
# 800/800 [==============================] - 1s 926us/step - loss: 0.3390 - accuracy: 0.8617
# Epoch 10/100
# 800/800 [==============================] - 1s 898us/step - loss: 0.3468 - accuracy: 0.8580
# Epoch 11/100
# 800/800 [==============================] - 1s 913us/step - loss: 0.3511 - accuracy: 0.8557
# Epoch 12/100
# 800/800 [==============================] - 1s 924us/step - loss: 0.3514 - accuracy: 0.8570
# Epoch 13/100
# 800/800 [==============================] - 1s 899us/step - loss: 0.3540 - accuracy: 0.8539
# Epoch 14/100
# 800/800 [==============================] - 1s 882us/step - loss: 0.3495 - accuracy: 0.8615
# Epoch 15/100
# 800/800 [==============================] - 1s 935us/step - loss: 0.3362 - accuracy: 0.8625
# Epoch 16/100
# 800/800 [==============================] - 1s 966us/step - loss: 0.3543 - accuracy: 0.8544
# Epoch 17/100
# 800/800 [==============================] - 1s 961us/step - loss: 0.3438 - accuracy: 0.8574
# Epoch 18/100
# 800/800 [==============================] - 1s 929us/step - loss: 0.3385 - accuracy: 0.8634
# Epoch 19/100
# 800/800 [==============================] - 1s 947us/step - loss: 0.3344 - accuracy: 0.8631
# Epoch 20/100
# 800/800 [==============================] - 1s 964us/step - loss: 0.3437 - accuracy: 0.8640
# Epoch 21/100
# 800/800 [==============================] - 1s 931us/step - loss: 0.3375 - accuracy: 0.8643
# Epoch 22/100
# 800/800 [==============================] - 1s 964us/step - loss: 0.3425 - accuracy: 0.8616
# Epoch 23/100
# 800/800 [==============================] - 1s 972us/step - loss: 0.3359 - accuracy: 0.8618
# Epoch 24/100
# 800/800 [==============================] - 1s 959us/step - loss: 0.3471 - accuracy: 0.8573
# Epoch 25/100
# 800/800 [==============================] - 1s 896us/step - loss: 0.3435 - accuracy: 0.8577
# Epoch 26/100
# 800/800 [==============================] - 1s 911us/step - loss: 0.3424 - accuracy: 0.8589
# Epoch 27/100
# 800/800 [==============================] - 1s 905us/step - loss: 0.3438 - accuracy: 0.8576
# Epoch 28/100
# 800/800 [==============================] - 1s 890us/step - loss: 0.3391 - accuracy: 0.8617
# Epoch 29/100
# 800/800 [==============================] - 1s 889us/step - loss: 0.3377 - accuracy: 0.8609
# Epoch 30/100
# 800/800 [==============================] - 1s 901us/step - loss: 0.3392 - accuracy: 0.8633
# Epoch 31/100
# 800/800 [==============================] - 1s 914us/step - loss: 0.3368 - accuracy: 0.8598
# Epoch 32/100
# 800/800 [==============================] - 1s 895us/step - loss: 0.3384 - accuracy: 0.8637
# Epoch 33/100
# 800/800 [==============================] - 1s 895us/step - loss: 0.3358 - accuracy: 0.8634
# Epoch 34/100
# 800/800 [==============================] - 1s 924us/step - loss: 0.3484 - accuracy: 0.8555
# Epoch 35/100
# 800/800 [==============================] - 1s 886us/step - loss: 0.3315 - accuracy: 0.8646
# Epoch 36/100
# 800/800 [==============================] - 1s 903us/step - loss: 0.3326 - accuracy: 0.8636
# Epoch 37/100
# 800/800 [==============================] - 1s 870us/step - loss: 0.3317 - accuracy: 0.8643
# Epoch 38/100
# 800/800 [==============================] - 1s 914us/step - loss: 0.3247 - accuracy: 0.8647
# Epoch 39/100
# 800/800 [==============================] - 1s 898us/step - loss: 0.3382 - accuracy: 0.8611
# Epoch 40/100
# 800/800 [==============================] - 1s 878us/step - loss: 0.3312 - accuracy: 0.8610
# Epoch 41/100
# 800/800 [==============================] - 1s 919us/step - loss: 0.3308 - accuracy: 0.8648
# Epoch 42/100
# 800/800 [==============================] - 1s 898us/step - loss: 0.3326 - accuracy: 0.8643
# Epoch 43/100
# 800/800 [==============================] - 1s 913us/step - loss: 0.3333 - accuracy: 0.8620
# Epoch 44/100
# 800/800 [==============================] - 1s 920us/step - loss: 0.3278 - accuracy: 0.8670
# Epoch 45/100
# 800/800 [==============================] - 1s 1000us/step - loss: 0.3391 - accuracy: 0.8637
# Epoch 46/100
# 800/800 [==============================] - 1s 977us/step - loss: 0.3349 - accuracy: 0.8662
# Epoch 47/100
# 800/800 [==============================] - 1s 943us/step - loss: 0.3231 - accuracy: 0.8693
# Epoch 48/100
# 800/800 [==============================] - 1s 967us/step - loss: 0.3259 - accuracy: 0.8664
# Epoch 49/100
# 800/800 [==============================] - 1s 956us/step - loss: 0.3375 - accuracy: 0.8606
# Epoch 50/100
# 800/800 [==============================] - 1s 949us/step - loss: 0.3347 - accuracy: 0.8604
# Epoch 51/100
# 800/800 [==============================] - 1s 900us/step - loss: 0.3395 - accuracy: 0.8616
# Epoch 52/100
# 800/800 [==============================] - 1s 899us/step - loss: 0.3403 - accuracy: 0.8596
# Epoch 53/100
# 800/800 [==============================] - 1s 912us/step - loss: 0.3354 - accuracy: 0.8606
# Epoch 54/100
# 800/800 [==============================] - 1s 904us/step - loss: 0.3283 - accuracy: 0.8682
# Epoch 55/100
# 800/800 [==============================] - 1s 915us/step - loss: 0.3319 - accuracy: 0.8641
# Epoch 56/100
# 800/800 [==============================] - 1s 910us/step - loss: 0.3308 - accuracy: 0.8673
# Epoch 57/100
# 800/800 [==============================] - 1s 882us/step - loss: 0.3369 - accuracy: 0.8604
# Epoch 58/100
# 800/800 [==============================] - 1s 914us/step - loss: 0.3360 - accuracy: 0.8610
# Epoch 59/100
# 800/800 [==============================] - 1s 901us/step - loss: 0.3341 - accuracy: 0.8626
# Epoch 60/100
# 800/800 [==============================] - 1s 900us/step - loss: 0.3428 - accuracy: 0.8593
# Epoch 61/100
# 800/800 [==============================] - 1s 918us/step - loss: 0.3308 - accuracy: 0.8672
# Epoch 62/100
# 800/800 [==============================] - 1s 949us/step - loss: 0.3235 - accuracy: 0.8694
# Epoch 63/100
# 800/800 [==============================] - 1s 909us/step - loss: 0.3297 - accuracy: 0.8633
# Epoch 64/100
# 800/800 [==============================] - 1s 915us/step - loss: 0.3379 - accuracy: 0.8632
# Epoch 65/100
# 800/800 [==============================] - 1s 902us/step - loss: 0.3238 - accuracy: 0.8721
# Epoch 66/100
# 800/800 [==============================] - 1s 911us/step - loss: 0.3366 - accuracy: 0.8619
# Epoch 67/100
# 800/800 [==============================] - 1s 936us/step - loss: 0.3420 - accuracy: 0.8583
# Epoch 68/100
# 800/800 [==============================] - 1s 917us/step - loss: 0.3331 - accuracy: 0.8625
# Epoch 69/100
# 800/800 [==============================] - 1s 876us/step - loss: 0.3263 - accuracy: 0.8641
# Epoch 70/100
# 800/800 [==============================] - 1s 933us/step - loss: 0.3237 - accuracy: 0.8696
# Epoch 71/100
# 800/800 [==============================] - 1s 954us/step - loss: 0.3394 - accuracy: 0.8619
# Epoch 72/100
# 800/800 [==============================] - 1s 975us/step - loss: 0.3431 - accuracy: 0.8554
# Epoch 73/100
# 800/800 [==============================] - 1s 945us/step - loss: 0.3412 - accuracy: 0.8596
# Epoch 74/100
# 800/800 [==============================] - 1s 965us/step - loss: 0.3326 - accuracy: 0.8611
# Epoch 75/100
# 800/800 [==============================] - 1s 991us/step - loss: 0.3287 - accuracy: 0.8634
# Epoch 76/100
# 800/800 [==============================] - 1s 994us/step - loss: 0.3276 - accuracy: 0.8648
# Epoch 77/100
# 594/800 [=====================>........] - ETA: 0s - loss: 0.3310 - accuracy: 0.8602

# %% [markdown]
# # Evaluasi Arsitektur ANN

# %%
from sklearn.metrics import confusion_matrix
prediksiNasabah = modelnya.predict(Soal_ujian)
hasilPrediksi = (prediksiNasabah > 0.5)
cm = confusion_matrix(Jawaban_ujian, hasilPrediksi)
print('Nilai Akurasi = ', (cm[0,0]+cm[1,1])/2000)
# Out:
# Nilai Akurasi =  0.862

# %% [markdown]
# # Pemanfaatan Model untuk melakukan prediksi tunggal

# %% [markdown]
# Record tunggal seorang nasabah baru, mencoba memprediksi ouput record tunggal dari fitur-fitur yang ada.
#
# * Geography: Mumbai
# * Credit Score: 645
# * Gender: Male
# * Age: 40
# * Tenure: 3
# * Balance: 6000
# * Number of Product: 2
# * Has Credit Card: Yes
# * Is Active Member: Yes
# * Estimated Salary: 50000

# %%
import numpy as n
nasabahBaru = ss.transform(n.array([[1,0,   # Mumbai
                                     645,   # Credit Score
                                     1,     # Male
                                     40,    # Age
                                     3,     # Tenure
                                     6000,  # Balance
                                     2,     # Number of Product
                                     1,     # Has Credit Card: Yes
                                     1,     # Is Active Member: Yes
                                     50000  # Estimated Salary
                                     ]]))

hasilPrediksi = modelnya.predict(nasabahBaru)
prediksinya = (hasilPrediksi > 0.5)

if (prediksinya):
    print("Nasabah meninggalkan Bank")
else:
    print("Nasbah akan tetap di Bank")
